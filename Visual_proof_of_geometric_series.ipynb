# %% [markdown]
# Rick Mabry's visual proof of
#
# $$1+ \frac 1 4 + \left( \frac 1 4 \right)^2 +  \left( \frac 1 4 \right)^3 + \cdots = \frac 1 3$$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Viewpoints 2000 Group very neat proof for the general geometric series:
#
# ![image.png](data:image/png;base64,...)
